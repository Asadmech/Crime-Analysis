# %%
import pandas as pd

# %%
crime_data = pd.read_csv("Crime_Data_from_2020_to_Present.csv")

# %%
crime_data.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
crime_data.tail(40)
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 901317  231309462  04/20/2023 12:00:00 AM  04/20/2023 12:00:00 AM       900
# 901318  230317497  10/02/2023 12:00:00 AM  10/01/2023 12:00:00 AM      2205
# 901319  231014386  10/03/2023 12:00:00 AM  10/03/2023 12:00:00 AM       240
# 901320  231611415  08/21/2023 12:00:00 AM  08/04/2023 12:00:00 AM      1400
# 901321  231314924  08/02/2023 12:00:00 AM  08/02/2023 12:00:00 AM      1432
# 901322  231225413  12/22/2023 12:00:00 AM  12/21/2023 12:00:00 AM      1600
# 901323  230509679  06/07/2023 12:00:00 AM  06/07/2023 12:00:00 AM      2045
# 901324  231300825  06/07/2023 12:00:00 AM  06/07/2023 12:00:00 AM      2203
# 901325  230908346  04/19/2023 12:00:00 AM  04/18/2023 12:00:00 AM      2243
# 901326  231608412  05/21/2023 12:00:00 AM  05/20/2023 12:00:00 AM      2130
# 901327  230512110  08/09/2023 12:00:00 AM  08/09/2023 12:00:00 AM      1310
# ...

# %%
z_area =(crime_data["AREA NAME"] == "").sum()

# %%
z_area
# Out:
# 0

# %%
len(crime_data["AREA NAME"])
# Out:
# 901357

# %%
crime_data["AREA NAME"].value_counts()
# Out:
# AREA NAME
# Central        61416
# 77th Street    56381
# Pacific        52537
# Southwest      50654
# Hollywood      47508
# Southeast      45503
# Olympic        45486
# N Hollywood    45124
# Newton         45032
# Wilshire       43191
# Rampart        42548
# West LA        41300
# Northeast      38810
# Van Nuys       38056
# West Valley    37857
# Harbor         37086
# Topanga        36814
# Devonshire     36747
# Mission        35849
# Hollenbeck     33662
# Foothill       29796
# Name: count, dtype: int64

# %%
crime_data["AREA NAME"].value_counts(normalize = True)
# Out:
# AREA NAME
# Central        0.068137
# 77th Street    0.062551
# Pacific        0.058287
# Southwest      0.056197
# Hollywood      0.052707
# Southeast      0.050483
# Olympic        0.050464
# N Hollywood    0.050062
# Newton         0.049960
# Wilshire       0.047918
# Rampart        0.047204
# West LA        0.045820
# Northeast      0.043057
# Van Nuys       0.042221
# West Valley    0.042000
# Harbor         0.041145
# Topanga        0.040843
# Devonshire     0.040769
# Mission        0.039772
# Hollenbeck     0.037346
# Foothill       0.033057
# Name: proportion, dtype: float64

# %%
most_crime_area = crime_data["AREA NAME"].value_counts(normalize = True)

# %%
most_crime_area.sort_values(ascending = False)
# Out:
# AREA NAME
# Central        0.068137
# 77th Street    0.062551
# Pacific        0.058287
# Southwest      0.056197
# Hollywood      0.052707
# Southeast      0.050483
# Olympic        0.050464
# N Hollywood    0.050062
# Newton         0.049960
# Wilshire       0.047918
# Rampart        0.047204
# West LA        0.045820
# Northeast      0.043057
# Van Nuys       0.042221
# West Valley    0.042000
# Harbor         0.041145
# Topanga        0.040843
# Devonshire     0.040769
# Mission        0.039772
# Hollenbeck     0.037346
# Foothill       0.033057
# Name: proportion, dtype: float64

# %%
high_crime_areas =most_crime_area > 0.05 # make a boolean logic

# %%
high_crime_areas
# Out:
# AREA NAME
# Central         True
# 77th Street     True
# Pacific         True
# Southwest       True
# Hollywood       True
# Southeast       True
# Olympic         True
# N Hollywood     True
# Newton         False
# Wilshire       False
# Rampart        False
# West LA        False
# Northeast      False
# Van Nuys       False
# West Valley    False
# Harbor         False
# Topanga        False
# Devonshire     False
# Mission        False
# Hollenbeck     False
# Foothill       False
# Name: proportion, dtype: bool

# %%
most_crime_area[high_crime_areas]
# Out:
# AREA NAME
# Central        0.068137
# 77th Street    0.062551
# Pacific        0.058287
# Southwest      0.056197
# Hollywood      0.052707
# Southeast      0.050483
# Olympic        0.050464
# N Hollywood    0.050062
# Name: proportion, dtype: float64

# %%
most_cr_bol = most_crime_area[high_crime_areas].index

# %%
most_cr = crime_data["AREA NAME"].isin(most_cr_bol)

# %%
most_cr
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 901352    False
# 901353     True
# 901354     True
# 901355    False
# 901356     True
# Name: AREA NAME, Length: 901357, dtype: bool

# %%
crime_data[most_cr] #Here ,the data of most crime areas has been seperated from the rest.
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# 5       231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300
# 6       230110144  04/04/2023 12:00:00 AM  07/03/2020 12:00:00 AM       900
# ...           ...                     ...                     ...       ...
# 901346  230126819  12/19/2023 12:00:00 AM  12/19/2023 12:00:00 AM      1800
# 901350  230115595  07/08/2023 12:00:00 AM  07/08/2023 12:00:00 AM      1230
# 901353  230618716  12/07/2023 12:00:00 AM  12/01/2023 12:00:00 AM      1000
# 901354  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 901356  230319786  11/10/2023 12:00:00 AM  11/09/2023 12:00:00 AM      2300
#
# ...

# %%
TCA = crime_data[most_cr] # TCA = Top Crime Areas

# %% [markdown]
# # Now we will find the which type of crime occur most in top crime areas ?

# %%
TCA.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
# 5  231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300    18
# 6  230110144  04/04/2023 12:00:00 AM  07/03/2020 12:00:00 AM       900     1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd            Crm Cd Desc  ...  \
# 1    Central          182         1     330  BURGLARY FROM VEHICLE  ...
# 2  Southwest          356         1     480          BIKE - STOLEN  ...
# 4  Hollywood          666         2     354      THEFT OF IDENTITY  ...
# 5  Southeast         1826         2     354      THEFT OF IDENTITY  ...
# 6    Central          182         2     354      THEFT OF IDENTITY  ...
#
#   Status  Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# ...

# %%
TCA.rename(columns = {'Crm Cd Desc' :'Crime Name' })
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# 5       231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300
# 6       230110144  04/04/2023 12:00:00 AM  07/03/2020 12:00:00 AM       900
# ...           ...                     ...                     ...       ...
# 901346  230126819  12/19/2023 12:00:00 AM  12/19/2023 12:00:00 AM      1800
# 901350  230115595  07/08/2023 12:00:00 AM  07/08/2023 12:00:00 AM      1230
# 901353  230618716  12/07/2023 12:00:00 AM  12/01/2023 12:00:00 AM      1000
# 901354  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 901356  230319786  11/10/2023 12:00:00 AM  11/09/2023 12:00:00 AM      2300
#
# ...

# %%
TCA = TCA.rename(columns = {'Crm Cd Desc' :'Crime Name' })

# %%
TCA
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# 5       231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300
# 6       230110144  04/04/2023 12:00:00 AM  07/03/2020 12:00:00 AM       900
# ...           ...                     ...                     ...       ...
# 901346  230126819  12/19/2023 12:00:00 AM  12/19/2023 12:00:00 AM      1800
# 901350  230115595  07/08/2023 12:00:00 AM  07/08/2023 12:00:00 AM      1230
# 901353  230618716  12/07/2023 12:00:00 AM  12/01/2023 12:00:00 AM      1000
# 901354  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 901356  230319786  11/10/2023 12:00:00 AM  11/09/2023 12:00:00 AM      2300
#
# ...

# %%
TCA["Crime Name"].value_counts()
# Out:
# Crime Name
# VEHICLE - STOLEN                                           41177
# BATTERY - SIMPLE ASSAULT                                   34011
# BURGLARY FROM VEHICLE                                      26794
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT             26643
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)    24564
#                                                            ...
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                       2
# THEFT, COIN MACHINE - ATTEMPT                                  2
# MANSLAUGHTER, NEGLIGENT                                        2
# BLOCKING DOOR INDUCTION CENTER                                 1
# DISHONEST EMPLOYEE ATTEMPTED THEFT                             1
# Name: count, Length: 138, dtype: int64

# %%
a=(TCA["Crime Name"] == "").sum() # to check if there are an empty string in Crime Names

# %%
a
# Out:
# 0

# %%
TCA["Crime Name"].value_counts(normalize = True)
# Out:
# Crime Name
# VEHICLE - STOLEN                                           0.101770
# BATTERY - SIMPLE ASSAULT                                   0.084059
# BURGLARY FROM VEHICLE                                      0.066222
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT             0.065849
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)    0.060710
#                                                              ...
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                   0.000005
# THEFT, COIN MACHINE - ATTEMPT                              0.000005
# MANSLAUGHTER, NEGLIGENT                                    0.000005
# BLOCKING DOOR INDUCTION CENTER                             0.000002
# DISHONEST EMPLOYEE ATTEMPTED THEFT                         0.000002
# Name: proportion, Length: 138, dtype: float64

# %%
Top_Crimes =TCA["Crime Name"].value_counts(normalize = True)

# %%
Top_C_log =Top_Crimes > 0.05

# %%
Top_Crimes[Top_C_log]
# Out:
# Crime Name
# VEHICLE - STOLEN                                           0.101770
# BATTERY - SIMPLE ASSAULT                                   0.084059
# BURGLARY FROM VEHICLE                                      0.066222
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT             0.065849
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)    0.060710
# THEFT OF IDENTITY                                          0.056141
# THEFT PLAIN - PETTY ($950 & UNDER)                         0.054378
# BURGLARY                                                   0.051615
# INTIMATE PARTNER - SIMPLE ASSAULT                          0.050298
# Name: proportion, dtype: float64

# %%
Top_Crimes=Top_Crimes[Top_C_log]

# %%
Top_Crimes.index  # These are the most type of crime occurs in top crime areas .
# Out:
# Index(['VEHICLE - STOLEN', 'BATTERY - SIMPLE ASSAULT', 'BURGLARY FROM VEHICLE',
#        'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#        'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#        'THEFT OF IDENTITY', 'THEFT PLAIN - PETTY ($950 & UNDER)', 'BURGLARY',
#        'INTIMATE PARTNER - SIMPLE ASSAULT'],
#       dtype='object', name='Crime Name')

# %%
strt_77=(TCA["AREA NAME"] == "77th Street").sum()

# %% [markdown]
# #####

# %%
strt_77
# Out:
# 56381

# %%
strt_77_df = TCA[TCA["AREA NAME"] == "77th Street"]

# %%
strt_77_df
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 30      211209197  03/20/2021 12:00:00 AM  07/01/2020 12:00:00 AM      1425
# 32      231207725  02/27/2023 12:00:00 AM  01/27/2020 12:00:00 AM       635
# 33      231205231  01/17/2023 12:00:00 AM  01/01/2020 12:00:00 AM      1535
# 37      211220472  09/27/2021 12:00:00 AM  11/26/2020 12:00:00 AM      2000
# 43      231210407  04/18/2023 12:00:00 AM  01/01/2020 12:00:00 AM         1
# ...           ...                     ...                     ...       ...
# 901276  231223960  11/22/2023 12:00:00 AM  11/22/2023 12:00:00 AM      1345
# 901281  231217487  08/11/2023 12:00:00 AM  08/11/2023 12:00:00 AM      1900
# 901306  231209545  04/04/2023 12:00:00 AM  04/04/2023 12:00:00 AM       910
# 901312  231212224  05/17/2023 12:00:00 AM  05/17/2023 12:00:00 AM      2300
# 901322  231225413  12/22/2023 12:00:00 AM  12/21/2023 12:00:00 AM      1600
#
# ...

# %%
strt_77_df["Crime Name"].value_counts(ascending = False) # Just to check what type of crime specifically occur in 77th street,
# Out:
# Crime Name
# VEHICLE - STOLEN                                  7428
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    5582
# BATTERY - SIMPLE ASSAULT                          4431
# THEFT OF IDENTITY                                 3990
# INTIMATE PARTNER - SIMPLE ASSAULT                 3877
#                                                   ...
# GRAND THEFT / AUTO REPAIR                            1
# DISHONEST EMPLOYEE - GRAND THEFT                     1
# CONSPIRACY                                           1
# COUNTERFEIT                                          1
# INCITING A RIOT                                      1
# Name: count, Length: 116, dtype: int64

# %% [markdown]
# # Now we will check at which time most crime occurs ?

# %%
TCA.head(20)
# Out:
#         DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 1   200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2   200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 4   220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
# 5   231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300    18
# 6   230110144  04/04/2023 12:00:00 AM  07/03/2020 12:00:00 AM       900     1
# 7   220314085  07/22/2022 12:00:00 AM  05/12/2020 12:00:00 AM      1110     3
# 10  221804943  01/21/2022 12:00:00 AM  07/01/2020 12:00:00 AM      1335    18
# 16  230312288  06/01/2023 12:00:00 AM  02/02/2020 12:00:00 AM       315     3
# 17  231805781  02/03/2023 12:00:00 AM  07/01/2020 12:00:00 AM       805    18
# 25  232011098  06/04/2023 12:00:00 AM  07/01/2020 12:00:00 AM      1200    20
# 30  211209197  03/20/2021 12:00:00 AM  07/01/2020 12:00:00 AM      1425    12
# ...

# %%
import datetime as dt

# %%
TCA["TIME OCC"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 404609 entries, 1 to 901356
# Series name: TIME OCC
# Non-Null Count   Dtype
# --------------   -----
# 404609 non-null  int64
# dtypes: int64(1)
# memory usage: 6.2 MB

# %%
TCA["TIME OCC"].value_counts().head(24)
# Out:
# TIME OCC
# 1200    12744
# 1800     9987
# 2000     9522
# 1700     9446
# 2200     9128
# 1900     8926
# 2100     8658
# 1600     8134
# 1500     7906
# 1        7294
# 2300     7276
# 1400     7178
# 1000     6662
# 1300     6244
# 800      6123
# 1100     5952
# 900      5444
# 100      5121
# 1930     4395
# 1830     4389
# 200      4346
# 1730     4216
# 2030     4128
# 2130     4112
# Name: count, dtype: int64

# %%
TCA["TIME OCC"].astype(str)
# Out:
# 1         1800
# 2         1700
# 4         1200
# 5         2300
# 6          900
#           ...
# 901346    1800
# 901350    1230
# 901353    1000
# 901354       1
# 901356    2300
# Name: TIME OCC, Length: 404609, dtype: object

# %%
TCA["TIME OCC"].astype(str).str.len() ==4
# Out:
# 1          True
# 2          True
# 4          True
# 5          True
# 6         False
#           ...
# 901346     True
# 901350     True
# 901353     True
# 901354    False
# 901356     True
# Name: TIME OCC, Length: 404609, dtype: bool

# %%
bol_time=TCA["TIME OCC"].astype(str).str.len() ==4

# %%
c_time=TCA["TIME OCC"]

# %%
c_time[bol_time]
# Out:
# 1         1800
# 2         1700
# 4         1200
# 5         2300
# 7         1110
#           ...
# 901345    1100
# 901346    1800
# 901350    1230
# 901353    1000
# 901356    2300
# Name: TIME OCC, Length: 289170, dtype: int64

# %%
cc_time = c_time[bol_time]

# %%
TCA["TIME OCC"].isin(cc_time)
# Out:
# 1          True
# 2          True
# 4          True
# 5          True
# 6         False
#           ...
# 901346     True
# 901350     True
# 901353     True
# 901354    False
# 901356     True
# Name: TIME OCC, Length: 404609, dtype: bool

# %%
cor_f_t=TCA["TIME OCC"].isin(cc_time)

# %%
TCA[cor_f_t]
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200
# 5       231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM      2300
# 7       220314085  07/22/2022 12:00:00 AM  05/12/2020 12:00:00 AM      1110
# ...           ...                     ...                     ...       ...
# 901345  231510379  05/29/2023 12:00:00 AM  05/25/2023 12:00:00 AM      1100
# 901346  230126819  12/19/2023 12:00:00 AM  12/19/2023 12:00:00 AM      1800
# 901350  230115595  07/08/2023 12:00:00 AM  07/08/2023 12:00:00 AM      1230
# 901353  230618716  12/07/2023 12:00:00 AM  12/01/2023 12:00:00 AM      1000
# 901356  230319786  11/10/2023 12:00:00 AM  11/09/2023 12:00:00 AM      2300
#
# ...

# %%
Time_Cor_TCA = TCA[cor_f_t]

# %%
pd.to_datetime(Time_Cor_TCA["TIME OCC"], format = '%H%M')
# Out:
# 1        1900-01-01 18:00:00
# 2        1900-01-01 17:00:00
# 4        1900-01-01 12:00:00
# 5        1900-01-01 23:00:00
# 7        1900-01-01 11:10:00
#                  ...
# 901345   1900-01-01 11:00:00
# 901346   1900-01-01 18:00:00
# 901350   1900-01-01 12:30:00
# 901353   1900-01-01 10:00:00
# 901356   1900-01-01 23:00:00
# Name: TIME OCC, Length: 289170, dtype: datetime64[ns]

# %%
Time_Cor_TCA.loc[:,"TIME OCC"]=pd.to_datetime(Time_Cor_TCA["TIME OCC"], format = '%H%M')

# %%
Time_Cor_TCA
# Out:
#             DR_NO               Date Rptd                DATE OCC  \
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM
# 5       231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM
# 7       220314085  07/22/2022 12:00:00 AM  05/12/2020 12:00:00 AM
# ...           ...                     ...                     ...
# 901345  231510379  05/29/2023 12:00:00 AM  05/25/2023 12:00:00 AM
# 901346  230126819  12/19/2023 12:00:00 AM  12/19/2023 12:00:00 AM
# 901350  230115595  07/08/2023 12:00:00 AM  07/08/2023 12:00:00 AM
# 901353  230618716  12/07/2023 12:00:00 AM  12/01/2023 12:00:00 AM
# 901356  230319786  11/10/2023 12:00:00 AM  11/09/2023 12:00:00 AM
#
#                   TIME OCC  AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 1      1900-01-01 18:00:00     1      Central          182         1     330
# ...

# %%
Time_Cor_TCA.loc[:,["TIME OCC"]]=Time_Cor_TCA["TIME OCC"].dt.time

# %%
Time_Cor_TCA
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1       200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM  18:00:00
# 2       200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM  17:00:00
# 4       220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM  12:00:00
# 5       231808869  04/04/2023 12:00:00 AM  12/01/2020 12:00:00 AM  23:00:00
# 7       220314085  07/22/2022 12:00:00 AM  05/12/2020 12:00:00 AM  11:10:00
# ...           ...                     ...                     ...       ...
# 901345  231510379  05/29/2023 12:00:00 AM  05/25/2023 12:00:00 AM  11:00:00
# 901346  230126819  12/19/2023 12:00:00 AM  12/19/2023 12:00:00 AM  18:00:00
# 901350  230115595  07/08/2023 12:00:00 AM  07/08/2023 12:00:00 AM  12:30:00
# 901353  230618716  12/07/2023 12:00:00 AM  12/01/2023 12:00:00 AM  10:00:00
# 901356  230319786  11/10/2023 12:00:00 AM  11/09/2023 12:00:00 AM  23:00:00
#
# ...

# %%
Time_Cor_TCA["TIME OCC"].value_counts()
# Out:
# TIME OCC
# 12:00:00    12744
# 18:00:00     9987
# 20:00:00     9522
# 17:00:00     9446
# 22:00:00     9128
#             ...
# 23:32:00       11
# 22:39:00       11
# 22:51:00       11
# 22:29:00        9
# 22:31:00        7
# Name: count, Length: 840, dtype: int64

# %% [markdown]
# # it has been found out that 6PM to 8PM , around 5PM and 12:00 Noon , they are the most dangerous time to visit in Top Crime Areas to visit.

# %%
Time_Cor_TCA.loc[:,"Date Rptd"]=Time_Cor_TCA["Date Rptd"].str.replace("AM" ,"")

# %%
Time_Cor_TCA.loc[:,"DATE OCC"]=Time_Cor_TCA["DATE OCC"].str.replace("AM" ,"")

# %%
pd.to_datetime(Time_Cor_TCA["Date Rptd"])
# Out:
# 1        2020-02-09 12:00:00
# 2        2020-11-11 12:00:00
# 4        2022-08-18 12:00:00
# 5        2023-04-04 12:00:00
# 7        2022-07-22 12:00:00
#                  ...
# 901345   2023-05-29 12:00:00
# 901346   2023-12-19 12:00:00
# 901350   2023-07-08 12:00:00
# 901353   2023-12-07 12:00:00
# 901356   2023-11-10 12:00:00
# Name: Date Rptd, Length: 289170, dtype: datetime64[ns]

# %%
Time_Cor_TCA.loc[:,"Date Rptd"]=pd.to_datetime(Time_Cor_TCA["Date Rptd"])

# %%
pd.to_datetime(Time_Cor_TCA["DATE OCC"])
# Out:
# 1        2020-02-08 12:00:00
# 2        2020-11-04 12:00:00
# 4        2020-08-17 12:00:00
# 5        2020-12-01 12:00:00
# 7        2020-05-12 12:00:00
#                  ...
# 901345   2023-05-25 12:00:00
# 901346   2023-12-19 12:00:00
# 901350   2023-07-08 12:00:00
# 901353   2023-12-01 12:00:00
# 901356   2023-11-09 12:00:00
# Name: DATE OCC, Length: 289170, dtype: datetime64[ns]

# %%
Time_Cor_TCA.loc[:,"DATE OCC"]=pd.to_datetime(Time_Cor_TCA["DATE OCC"])

# %%
Time_Cor_TCA # converted Date Rptd and DATE OCC coulns into datetype object
# Out:
#             DR_NO            Date Rptd             DATE OCC  TIME OCC  AREA  \
# 1       200106753  2020-02-09 12:00:00  2020-02-08 12:00:00  18:00:00     1
# 2       200320258  2020-11-11 12:00:00  2020-11-04 12:00:00  17:00:00     3
# 4       220614831  2022-08-18 12:00:00  2020-08-17 12:00:00  12:00:00     6
# 5       231808869  2023-04-04 12:00:00  2020-12-01 12:00:00  23:00:00    18
# 7       220314085  2022-07-22 12:00:00  2020-05-12 12:00:00  11:10:00     3
# ...           ...                  ...                  ...       ...   ...
# 901345  231510379  2023-05-29 12:00:00  2023-05-25 12:00:00  11:00:00    15
# 901346  230126819  2023-12-19 12:00:00  2023-12-19 12:00:00  18:00:00     1
# 901350  230115595  2023-07-08 12:00:00  2023-07-08 12:00:00  12:30:00     1
# 901353  230618716  2023-12-07 12:00:00  2023-12-01 12:00:00  10:00:00     6
# 901356  230319786  2023-11-10 12:00:00  2023-11-09 12:00:00  23:00:00     3
#
#           AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# ...

# %%
# Want to check if crime equally occurs to both men and women  ?

# %%
Time_Cor_TCA.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crime Name', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
Time_Cor_TCA["Vict Sex"].value_counts()
# Out:
# Vict Sex
# M    115827
# F    106370
# X     28542
# H        28
# -         1
# Name: count, dtype: int64

# %%
Time_Cor_TCA["Vict Sex"].value_counts(normalize = True)
# Out:
# Vict Sex
# M    0.461889
# F    0.424177
# X    0.113818
# H    0.000112
# -    0.000004
# Name: proportion, dtype: float64

# %%
Time_Cor_TCA["Vict Age"].value_counts()
# Out:
# Vict Age
#  0     70284
#  30     6992
#  29     6820
#  28     6594
#  31     6503
#        ...
#  96       19
#  95       17
# -1        14
# -2         3
# -4         3
# Name: count, Length: 102, dtype: int64

# %%
import numpy as np

# %%
Time_Cor_TCA["Vict Age"].replace(0,np.nan)
# Out:
# 1         47.0
# 2         19.0
# 4         28.0
# 5         41.0
# 7         27.0
#           ...
# 901345    25.0
# 901346    64.0
# 901350    35.0
# 901353    30.0
# 901356    38.0
# Name: Vict Age, Length: 289170, dtype: float64

# %%
Time_Cor_TCA.loc[:,"Vict Age"]=Time_Cor_TCA["Vict Age"].replace(0,np.nan)

# %%
Time_Cor_TCA["Vict Age"].dropna
# Out:
# <bound method Series.dropna of 1         47.0
# 2         19.0
# 4         28.0
# 5         41.0
# 7         27.0
#           ...
# 901345    25.0
# 901346    64.0
# 901350    35.0
# 901353    30.0
# 901356    38.0
# Name: Vict Age, Length: 289170, dtype: float64>

# %%
Time_Cor_TCA.loc[:,"Vict Age"].dropna=Time_Cor_TCA["Vict Age"].dropna

# %% [markdown]
# ### Result/Suggestion= People should avoid visiting to Central , 77th Street, Pacific , Southwest,Hollywood from 5 to 8 PM and 12 Noon especially in vehicles. These are hot spots for crimes to happen.
